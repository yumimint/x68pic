# %% [markdown]
# <a href="https://colab.research.google.com/github/yumimint/x68pic/blob/develop/picloader.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
try:
    import x68pic
except ModuleNotFoundError:
    # %pip install git+https://github.com/yumimint/x68pic.git@develop
    import x68pic

import requests

req = requests.get("https://github.com/yumimint/colab/raw/refs/heads/main/clipboard_1776343615.pic")
im = x68pic.decode(req.content)
im.resize((im.size[0] * 4 // 3, im.size[1]))
# Out:
# ...
#   Cloning https://github.com/yumimint/x68pic.git (to revision develop) to /tmp/pip-req-build-o6_nj2_0
#   Running command git clone --filter=blob:none --quiet https://github.com/yumimint/x68pic.git /tmp/pip-req-build-o6_nj2_0
#   Running command git checkout -b develop --track origin/develop
#   Switched to a new branch 'develop'
#   Branch 'develop' set up to track remote branch 'develop' from 'origin'.
#   Resolved https://github.com/yumimint/x68pic.git to commit 44e79f73070235af7f0ceb6458dd79eea5c1af57
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for x68pic: filename=x68pic-2026.4.16-py3-none-any.whl size=20722 sha256=2036316e9061ee48f0c0a29f3571d149d003534c0558c0d1dcc4e44491a5c26e
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ela4ntwl/wheels/81/0a/22/b6721131adbaf42d64fb7539c1d5c45595eb083414457bbb9c
# Successfully built x68pic
# ...
